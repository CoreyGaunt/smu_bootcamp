# %%
import pandas as pd
import os
import csv

# %%
ted = os.path.join("ted_talks.csv")

# %%
ted_df = pd.read_csv(ted)
ted_df.head(3)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event  languages  main_speaker  \
# 0  TED2006         60  Ken Robinson
# 1  TED2006         43       Al Gore
# 2  TED2006         26   David Pogue
#
#                                         name                        title  \
# 0  Ken Robinson: Do schools kill creativity?  Do schools kill creativity?
# 1       Al Gore: Averting the climate crisis  Averting the climate crisis
# 2              David Pogue: Simplicity sells             Simplicity sells
#
#       views
# 0  47227110
# 1   3200520
# 2   1636292

# %%
max_views = ted_df["views"].max()
min_views = ted_df["views"].min()

max_views

bins = [0,100000,500000,1000000,1500000,2000000,3000000,10000000]

names = ["G Class","F Class","E Class","D Class","C Class","B Class","A Class"]

# %%
ted_df["View Group"] = pd.cut(ted_df["views"], bins, labels=names,include_lowest=True)
ted_df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event  languages         main_speaker  \
# ...

# %%
ted_df_sum = ted_df.groupby("View Group")

print(ted_df_sum['comments'].count())

ted_sum = ted_df_sum[["comments","duration","languages"]].mean()
#ted_df2= ted_df_sum.max()
ted_sum
#ted_df2.head()
# Out:
# View Group
# G Class      3
# F Class    276
# E Class    768
# D Class    701
# C Class    303
# B Class    239
# A Class    226
# Name: comments, dtype: int64
#               comments     duration  languages
# View Group
# G Class      35.333333  1591.666667   0.000000
# F Class      90.336957   825.018116  18.967391
# E Class     118.005208   830.218750  24.733073
# D Class     147.875892   794.118402  27.055635
# C Class     215.009901   846.409241  29.851485
# B Class     299.481172   832.430962  32.807531
# A Class     436.008850   852.530973  35.938053

# %%
ted_df2.sort_values("View Group",ascending=False)
# Out:
#             comments                                        description  \
# View Group
# A Class         6404  You’re doing everything right at work, taking ...
# B Class         2673  “People are so afraid of variety that they try...
# C Class         2492  “If you really want to know a people, start by...
# D Class         1502  iPad storyteller Joe Sabia introduces us to Lo...
# E Class          846  “Men fight wars, and women mourn them,” says d...
# F Class          649  Zambia-born filmmaker Franco Sacchi tours us t...
# G Class           43  There are millions of prodigiously gifted musi...
#
#             duration                     event  languages  \
# View Group
# A Class         2450    World Science Festival         72
# B Class         1485           TEDxZurich 2012         69
# C Class         3608               Taste3 2008         54
# D Class         2010       Toronto Youth Corps         52
# E Class         4587         Web 2.0 Expo 2008         61
# ...
